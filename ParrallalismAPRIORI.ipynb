# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarthak-Jadhav-Dev/ParrallalismInAPRIORI/blob/main/ParrallalismAPRIORI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Apriori with GPU-accelerated support counting (CUDA)
# This notebook compiles and runs a CUDA-accelerated Apriori (counting step on GPU).
# Steps:
# 1. Ensure GPU runtime is enabled (Runtime → Change runtime type → GPU).
# 2. Check `nvcc`. If missing, try the automatic install.
# 3. Compile and run the CUDA C++ program.
#
# #Points to Note:
# 1.Only parallelized the support counting step (the heavy inner loop) on the GPU. Candidate generation, I/O, and rule generation stay on the host (C++).

# %% [markdown]
# #The Code Below is to Make a Dataset File in CSV Format of Lakh Records

# %%
#The File Below is Just for making the dataset on the Google Colabs Runtime Storage
import random, csv

# Base transactions (realistic shopping baskets)
base = [
    ["bread","milk","eggs"],
    ["milk","laptop","beer","bread"],
    ["bread","butter","cheese"],
    ["mobile","headphones","powerbank"],
    ["laptop","mouse","keyboard"],
    ["shampoo","soap","toothpaste"],
    ["bread","milk","laptop"],
    ["eggs","flour","sugar","butter"],
    ["bread","butter","jam"],
    ["mobile","charger","cover"],
    ["laptop","mouse","pad","usb"],
    ["milk","cereal","bananas"],
    ["bread","milk","eggs","cheese"],
    ["chips","coke","chocolate"],
    ["rice","dal","oil","salt"],
    ["bread","eggs","flour","milk"],
    ["sofa","table","chair"],
    ["tshirt","jeans","shoes"],
    ["bread","butter","milk"],
    ["laptop","wipes","baby_powder"]
]

# Parameters
num_transactions = 100000   # make it big enough
filename = "realistic_dataset.csv"

# Write dataset
with open(filename, "w", newline="") as f:
    writer = csv.writer(f)
    for _ in range(num_transactions):
        transaction = random.choice(base)[:]     # pick a base basket
        # randomly drop/add one item to make variation
        if random.random() < 0.3:
            transaction = transaction[:-1]
        if random.random() < 0.3:
            transaction.append(random.choice(
                ["tea","coffee","cookies","fruits","yogurt","tv","fan","shoes"]
            ))
        writer.writerow(transaction)

print(f"Created {filename} with {num_transactions} realistic transactions")
# Out:
# Created realistic_dataset.csv with 100000 realistic transactions

# %% [markdown]
# #Check GPU & nvcc (runtime must be GPU)
#
# **nvcc** : nvcc stands for NVIDIA CUDA Compiler.
#
# 1.It is the compiler that comes with the CUDA Toolkit.
#
# 2.Purpose: It compiles programs that use CUDA (Compute Unified Device Architecture) — NVIDIA’s parallel programming model for GPUs.
#
# **nvcc handles both:**
#
# 1.CPU code (C/C++) → sends it to a normal host compiler (like g++ or clang).
#
# 2.GPU code (CUDA kernels) → compiles into GPU machine code (PTX/SASS).
#
# **Then it links them together into one executable.**

# %%
# Check GPU & nvcc presence
# !nvidia-smi
# !nvcc --version || echo "nvcc not found on this runtime"
# Out:
# Fri Sep 19 04:09:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %% [markdown]
# ##The Below Code Creates a `.cu` file in the Google Colab
#
# `.cu` is **File ending with .cu are just C++ source files that contain CUDA code.**

# %%
# %%bash
# cat > apriori_cuda.cu <<'EOF'
# /* Apriori GPU-accelerated (support counting on CUDA)
#    - built from user's APRIORI.cpp as basis
#    - kernel checks candidate presence using bitmask words (64-bit)
#    - compile with nvcc
# */
#
# #include <bits/stdc++.h>
# #include <cuda_runtime.h>
#
# using namespace std;
# using Item = string;
# using Itemset = set<Item>;
# using Transactions = vector<vector<Item>>;
# using FrequentItemsets = map<Itemset, double>;
# using Rules = vector<tuple<Itemset, Itemset, double, double>>;
#
# #define CUDA_CHECK(call)                                                     \
# do {                                                                         \
#     cudaError_t err = call;                                                  \
#     if (err != cudaSuccess) {                                                \
#         fprintf(stderr, "CUDA error at %s:%d: %s\n", __FILE__, __LINE__,     \
#                 cudaGetErrorString(err));                                    \
#         exit(EXIT_FAILURE);                                                  \
#     }                                                                        \
# } while(0)
#
# vector<Item> split_csv_line(const string &line) {
#     vector<Item> items;
#     stringstream ss(line);
#     string token;
#     while (getline(ss, token, ',')) {
#         auto start = token.find_first_not_of(" \n\r\t");
#         auto end = token.find_last_not_of(" \n\r\t");
#         if (start == string::npos) continue;
#         string t = token.substr(start, end - start + 1);
#         if (!t.empty()) items.push_back(t);
#     }
#     return items;
# }
#
# Transactions read_transactions(const string &filename) {
#     ifstream file(filename);
#     Transactions transactions;
#     if (!file) {
#         cerr << "Error: Unable to open file " << filename << endl;
#         return transactions;
#     }
#     string line;
#     while (getline(file, line)) {
#         auto tr = split_csv_line(line);
#         if (!tr.empty()) transactions.push_back(tr);
#     }
#     file.close();
#     return transactions;
# }
#
# vector<Itemset> create_candidate_itemsets(const Transactions &transactions, int k) {
#     set<Itemset> candidates;
#     if (k == 1) {
#         for (const auto &transaction : transactions) {
#             for (const auto &item : transaction) {
#                 candidates.insert(Itemset{item});
#             }
#         }
#     } else {
#         set<Item> all_items;
#         for (const auto &transaction : transactions) {
#             all_items.insert(transaction.begin(), transaction.end());
#         }
#         vector<Item> items_vector(all_items.begin(), all_items.end());
#         vector<bool> bitmask(k, true);
#         bitmask.resize(items_vector.size(), false);
#         do {
#             Itemset candidate;
#             for (int i = 0; i < (int)items_vector.size(); ++i) {
#                 if (bitmask[i]) candidate.insert(items_vector[i]);
#             }
#             if ((int)candidate.size() == k)
#                 candidates.insert(candidate);
#         } while (prev_permutation(bitmask.begin(), bitmask.end()));
#     }
#     return vector<Itemset>(candidates.begin(), candidates.end());
# }
#
# /* CUDA kernel: each thread checks one (candidate, transaction) pair.
#    trans_masks: num_transactions * M 64-bit words (flattened)
#    cand_masks:  num_candidates  * M 64-bit words (flattened)
#    counts:      num_candidates ints (atomicAdd)
# */
# extern "C" __global__
# void count_kernel(const unsigned long long *trans_masks,
#                   const unsigned long long *cand_masks,
#                   int M,
#                   int num_transactions,
#                   int num_candidates,
#                   int *counts) {
#     long long idx = (long long)blockIdx.x * blockDim.x + threadIdx.x;
#     long long total = (long long)num_candidates * (long long)num_transactions;
#     if (idx >= total) return;
#     int cand_idx = (int)(idx / num_transactions);
#     int trans_idx = (int)(idx % num_transactions);
#     const unsigned long long *t = trans_masks + (long long)trans_idx * M;
#     const unsigned long long *c = cand_masks + (long long)cand_idx * M;
#     bool ok = true;
#     for (int i = 0; i < M; ++i) {
#         if ((t[i] & c[i]) != c[i]) { ok = false; break; }
#     }
#     if (ok) atomicAdd(&counts[cand_idx], 1);
# }
#
# FrequentItemsets filter_itemsets_gpu(const Transactions &transactions,
#                                      const vector<Itemset> &candidates,
#                                      double min_support,
#                                      const unordered_map<Item,int> &item2id,
#                                      int M,
#                                      const vector<unsigned long long> &trans_masks) {
#     int num_transactions = (int)transactions.size();
#     int num_candidates = (int)candidates.size();
#     vector<int> counts(num_candidates, 0);
#     if (num_candidates == 0) return {};
#
#     // Build candidate masks on host
#     vector<unsigned long long> cand_masks((size_t)num_candidates * M, 0ULL);
#     for (int cidx = 0; cidx < num_candidates; ++cidx) {
#         for (const auto &it : candidates[cidx]) {
#             auto itid = item2id.find(it);
#             if (itid == item2id.end()) continue;
#             int id = itid->second;
#             int word = id / 64;
#             int bit = id % 64;
#             cand_masks[(size_t)cidx * M + word] |= (1ULL << bit);
#         }
#     }
#
#     // Device allocation for transactions (only once)
#     unsigned long long *d_trans = nullptr;
#     CUDA_CHECK(cudaMalloc(&d_trans, (size_t)num_transactions * M * sizeof(unsigned long long)));
#     CUDA_CHECK(cudaMemcpy(d_trans, trans_masks.data(), (size_t)num_transactions * M * sizeof(unsigned long long), cudaMemcpyHostToDevice));
#
#     // Batch candidates to limit memory and threads
#     const long long max_pairs = 10000000LL; // tune this value if needed
#     int batch_candidates = max(1, (int)min((long long)num_candidates, max_pairs / max(1, num_transactions)));
#     size_t offset = 0;
#     while (offset < (size_t)num_candidates) {
#         int this_batch = (int)min((size_t)batch_candidates, (size_t)num_candidates - offset);
#         unsigned long long *d_cands = nullptr;
#         int *d_counts = nullptr;
#         CUDA_CHECK(cudaMalloc(&d_cands, (size_t)this_batch * M * sizeof(unsigned long long)));
#         CUDA_CHECK(cudaMalloc(&d_counts, (size_t)this_batch * sizeof(int)));
#         CUDA_CHECK(cudaMemset(d_counts, 0, (size_t)this_batch * sizeof(int)));
#         CUDA_CHECK(cudaMemcpy(d_cands, cand_masks.data() + offset * M, (size_t)this_batch * M * sizeof(unsigned long long), cudaMemcpyHostToDevice));
#
#         long long total_pairs = (long long)this_batch * (long long)num_transactions;
#         int threads = 256;
#         long long blocks = (total_pairs + threads - 1) / threads;
#         if (blocks > 2147483647LL) {
#             fprintf(stderr, "Too many blocks required; reduce batch size.\n");
#             exit(EXIT_FAILURE);
#         }
#         count_kernel<<<(int)blocks, threads>>>(d_trans, d_cands, M, num_transactions, this_batch, d_counts);
#         CUDA_CHECK(cudaGetLastError());
#         CUDA_CHECK(cudaDeviceSynchronize());
#         vector<int> batch_counts(this_batch);
#         CUDA_CHECK(cudaMemcpy(batch_counts.data(), d_counts, (size_t)this_batch * sizeof(int), cudaMemcpyDeviceToHost));
#         for (int i = 0; i < this_batch; ++i) counts[offset + i] = batch_counts[i];
#         CUDA_CHECK(cudaFree(d_cands));
#         CUDA_CHECK(cudaFree(d_counts));
#         offset += this_batch;
#     }
#     CUDA_CHECK(cudaFree(d_trans));
#
#     FrequentItemsets frequent_itemsets;
#     for (int i = 0; i < num_candidates; ++i) {
#         double support = (double)counts[i] / (double)num_transactions;
#         if (support >= min_support) {
#             frequent_itemsets[candidates[i]] = support;
#         }
#     }
#     return frequent_itemsets;
# }
#
# FrequentItemsets apriori_gpu(const Transactions &transactions, double min_support) {
#     FrequentItemsets all_frequent_itemsets;
#     int k = 1;
#     // prepare item->id and trans_masks
#     set<Item> all_items_set;
#     for (const auto &t : transactions) all_items_set.insert(t.begin(), t.end());
#     vector<Item> all_items_vec(all_items_set.begin(), all_items_set.end());
#     unordered_map<Item,int> item2id;
#     for (int i = 0; i < (int)all_items_vec.size(); ++i) item2id[all_items_vec[i]] = i;
#     int num_items = (int)all_items_vec.size();
#     int M = (num_items + 63) / 64;
#     int num_transactions = (int)transactions.size();
#     vector<unsigned long long> trans_masks((size_t)num_transactions * M, 0ULL);
#     for (int ti = 0; ti < num_transactions; ++ti) {
#         for (const auto &it : transactions[ti]) {
#             int id = item2id[it];
#             int word = id / 64;
#             int bit = id % 64;
#             trans_masks[(size_t)ti * M + word] |= (1ULL << bit);
#         }
#     }
#
#     vector<Itemset> current_candidates = create_candidate_itemsets(transactions, k);
#     while (!current_candidates.empty()) {
#         FrequentItemsets frequent_itemsets = filter_itemsets_gpu(transactions, current_candidates, min_support, item2id, M, trans_masks);
#         if (frequent_itemsets.empty()) break;
#         for (const auto &p : frequent_itemsets) all_frequent_itemsets[p.first] = p.second;
#         ++k;
#         set<Item> items_in_frequent;
#         for (const auto &p : frequent_itemsets) items_in_frequent.insert(p.first.begin(), p.first.end());
#         vector<Item> items_vec(items_in_frequent.begin(), items_in_frequent.end());
#         vector<bool> bitmask(k, true);
#         bitmask.resize(items_vec.size(), false);
#         vector<Itemset> next_candidates;
#         do {
#             Itemset candidate;
#             for (int i = 0; i < (int)items_vec.size(); ++i) if (bitmask[i]) candidate.insert(items_vec[i]);
#             if ((int)candidate.size() == k) next_candidates.push_back(candidate);
#         } while (prev_permutation(bitmask.begin(), bitmask.end()));
#         current_candidates = next_candidates;
#     }
#     return all_frequent_itemsets;
# }
#
# vector<Itemset> generate_subsets(const Itemset &itemset) {
#     vector<Item> items(itemset.begin(), itemset.end());
#     vector<Itemset> subsets;
#     int n = (int)items.size();
#     for (int mask = 1; mask < (1 << n) - 1; ++mask) {
#         Itemset subset;
#         for (int i = 0; i < n; ++i) if (mask & (1 << i)) subset.insert(items[i]);
#         subsets.push_back(subset);
#     }
#     return subsets;
# }
#
# Rules generate_rules(const FrequentItemsets &frequent_itemsets, double min_confidence) {
#     Rules rules;
#     for (const auto &pair : frequent_itemsets) {
#         const Itemset &itemset = pair.first;
#         if (itemset.size() < 2) continue;
#         vector<Itemset> subsets = generate_subsets(itemset);
#         double itemset_support = pair.second;
#         for (const auto &antecedent : subsets) {
#             Itemset consequent;
#             set_difference(itemset.begin(), itemset.end(), antecedent.begin(), antecedent.end(), inserter(consequent, consequent.begin()));
#             if (consequent.empty()) continue;
#             auto it = frequent_itemsets.find(antecedent);
#             if (it != frequent_itemsets.end()) {
#                 double antecedent_support = it->second;
#                 double confidence = itemset_support / antecedent_support;
#                 if (confidence >= min_confidence) rules.emplace_back(antecedent, consequent, itemset_support, confidence);
#             }
#         }
#     }
#     return rules;
# }
#
# string itemset_to_string(const Itemset &itemset) {
#     string s = "{";
#     bool first = true;
#     for (const auto &item : itemset) {
#         if (!first) s += ", ";
#         s += item;
#         first = false;
#     }
#     s += "}";
#     return s;
# }
#
# int main(int argc, char** argv) {
#     string csv_file;
#     double min_support = 0.5, min_confidence = 0.7;
#     if (argc >= 4) {
#         csv_file = argv[1];
#         min_support = atof(argv[2]);
#         min_confidence = atof(argv[3]);
#     } else {
#         cout << "Enter CSV file name (e.g. dataset1.csv): ";
#         getline(cin, csv_file);
#         cout << "Enter minimum support (0-1): ";
#         cin >> min_support;
#         cout << "Enter minimum confidence (0-1): ";
#         cin >> min_confidence;
#     }
#
#     Transactions transactions = read_transactions(csv_file);
#     cout << "Loaded " << transactions.size() << " transactions." << endl;
#     if (!transactions.empty()) {
#         cout << "Sample transaction: ";
#         for (const auto &item : transactions[0]) cout << item << " ";
#         cout << endl;
#     }
#     FrequentItemsets frequent_itemsets = apriori_gpu(transactions, min_support);
#     if (!frequent_itemsets.empty()) {
#         cout << "\nFrequent Itemsets:" << endl;
#         for (const auto &p : frequent_itemsets) {
#             cout << itemset_to_string(p.first) << " -> support: " << p.second << endl;
#         }
#     } else {
#         cout << "\nNo frequent itemsets found with the given minimum support." << endl;
#     }
#     Rules rules = generate_rules(frequent_itemsets, min_confidence);
#     if (!rules.empty()) {
#         cout << "\nAssociation Rules:" << endl;
#         for (const auto &rule : rules) {
#             cout << itemset_to_string(get<0>(rule)) << " => " << itemset_to_string(get<1>(rule))
#                  << " (support: " << get<2>(rule) << ", confidence: " << get<3>(rule) << ")" << endl;
#         }
#     } else {
#         cout << "\nNo association rules found with the given minimum confidence." << endl;
#     }
#     return 0;
# }
# EOF
#
# echo "Wrote apriori_cuda.cu"
# Out:
# Wrote apriori_cuda.cu

# %% [markdown]
# ##The Blow Command will Compile it with nvcc

# %%
# !nvcc -arch=sm_75 apriori_cuda.cu -o apriori_cuda

# %% [markdown]
# ##Run the Compiled Code , the format of command is
# ```
# codename <datasetfile_name> <min_support> <min_confidence>
# ```

# %%
# !./apriori_cuda realistic_dataset.csv 0.01 0.5
#The Format is like filename min_support and then min_confidence
# Out:
# Loaded 100000 transactions.
# Sample transaction: laptop mouse keyboard
#
# Frequent Itemsets:
# {baby_powder} -> support: 0.03517
# {baby_powder, laptop} -> support: 0.03517
# {baby_powder, laptop, wipes} -> support: 0.03517
# {baby_powder, wipes} -> support: 0.03517
# {bananas} -> support: 0.03452
# {bananas, cereal} -> support: 0.03452
# {bananas, cereal, milk} -> support: 0.03452
# {bananas, milk} -> support: 0.03452
# {beer} -> support: 0.05049
# {beer, bread} -> support: 0.03558
# {beer, bread, laptop} -> support: 0.03558
# {beer, bread, laptop, milk} -> support: 0.03558
# {beer, bread, milk} -> support: 0.03558
# {beer, laptop} -> support: 0.05049
# {beer, laptop, milk} -> support: 0.05049
# {beer, milk} -> support: 0.05049
# {bread} -> support: 0.38714
# {bread, butter} -> support: 0.15111
# {bread, butter, cheese} -> support: 0.03549
# {bread, butter, jam} -> support: 0.03534
# {bread, butter, milk} -> support: 0.0355
# {bread, cheese} -> support: 0.07008
# {bread, cheese, eggs} -> support: 0.03459
# {bread, cheese, eggs, milk} -> support: 0.03459
# {bread, cheese, milk} -> support: 0.03459
# {bread, coffee} -> support: 0.01463
# {bread, cookies} -> support: 0.01536
# {bread, cookies, milk} -> support: 0.01033
# {bread, eggs} -> support: 0.13543
# {bread, eggs, flour} -> support: 0.05045
# {bread, eggs, flour, milk} -> support: 0.0351
# {bread, eggs, milk} -> support: 0.12008
# {bread, fan} -> support: 0.01472
# {bread, flour} -> support: 0.05045
# {bread, flour, milk} -> support: 0.0351
# {bread, fruits} -> support: 0.01417
# {bread, jam} -> support: 0.03534
# {bread, laptop} -> support: 0.07063
# {bread, laptop, milk} -> support: 0.07063
# {bread, milk} -> support: 0.25618
# {bread, shoes} -> support: 0.01434
# {bread, tea} -> support: 0.01451
# {bread, tv} -> support: 0.01386
# {bread, yogurt} -> support: 0.0137
# {butter} -> support: 0.18536
# {butter, cheese} -> support: 0.03549
# {butter, eggs} -> support: 0.03425
# {butter, eggs, flour} -> support: 0.03425
# {butter, eggs, flour, sugar} -> support: 0.03425
# {butter, eggs, sugar} -> support: 0.03425
# {butter, flour} -> support: 0.03425
# {butter, flour, sugar} -> support: 0.03425
# {butter, jam} -> support: 0.03534
# {butter, milk} -> support: 0.0355
# {butter, sugar} -> support: 0.03425
# {cereal} -> support: 0.04946
# {cereal, milk} -> support: 0.04946
# {chair} -> support: 0.03522
# {chair, sofa} -> support: 0.03522
# {chair, sofa, table} -> support: 0.03522
# {chair, table} -> support: 0.03522
# {charger} -> support: 0.04965
# {charger, cover} -> support: 0.03482
# {charger, cover, mobile} -> support: 0.03482
# {charger, mobile} -> support: 0.04965
# {cheese} -> support: 0.07008
# {cheese, eggs} -> support: 0.03459
# {cheese, eggs, milk} -> support: 0.03459
# {cheese, milk} -> support: 0.03459
# {chips} -> support: 0.04947
# {chips, chocolate} -> support: 0.03486
# {chips, chocolate, coke} -> support: 0.03486
# {chips, coke} -> support: 0.04947
# {chocolate} -> support: 0.03486
# {chocolate, coke} -> support: 0.03486
# {coffee} -> support: 0.03726
# {coffee, milk} -> support: 0.01168
# {coke} -> support: 0.04947
# {cookies} -> support: 0.03828
# {cookies, milk} -> support: 0.01293
# {cover} -> support: 0.03482
# {cover, mobile} -> support: 0.03482
# {dal} -> support: 0.05011
# {dal, oil} -> support: 0.05011
# {dal, oil, rice} -> support: 0.05011
# {dal, oil, rice, salt} -> support: 0.03508
# {dal, oil, salt} -> support: 0.03508
# {dal, rice} -> support: 0.05011
# {dal, rice, salt} -> support: 0.03508
# {dal, salt} -> support: 0.03508
# {eggs} -> support: 0.18501
# {eggs, flour} -> support: 0.10003
# {eggs, flour, milk} -> support: 0.0351
# {eggs, flour, sugar} -> support: 0.04958
# {eggs, milk} -> support: 0.12008
# {eggs, sugar} -> support: 0.04958
# {fan} -> support: 0.03774
# {fan, milk} -> support: 0.01212
# {flour} -> support: 0.10003
# {flour, milk} -> support: 0.0351
# {flour, sugar} -> support: 0.04958
# {fruits} -> support: 0.03706
# {fruits, milk} -> support: 0.01159
# {headphones} -> support: 0.05033
# {headphones, mobile} -> support: 0.05033
# {headphones, mobile, powerbank} -> support: 0.0352
# {headphones, powerbank} -> support: 0.0352
# {jam} -> support: 0.03534
# {jeans} -> support: 0.04973
# {jeans, shoes} -> support: 0.03532
# {jeans, shoes, tshirt} -> support: 0.03532
# {jeans, tshirt} -> support: 0.04973
# {keyboard} -> support: 0.03502
# {keyboard, laptop} -> support: 0.03502
# {keyboard, laptop, mouse} -> support: 0.03502
# {keyboard, mouse} -> support: 0.03502
# {laptop} -> support: 0.23458
# {laptop, milk} -> support: 0.08554
# {laptop, mouse} -> support: 0.09896
# {laptop, mouse, pad} -> support: 0.04883
# {laptop, mouse, pad, usb} -> support: 0.03386
# {laptop, mouse, usb} -> support: 0.03386
# {laptop, pad} -> support: 0.04883
# {laptop, pad, usb} -> support: 0.03386
# {laptop, usb} -> support: 0.03386
# {laptop, wipes} -> support: 0.05008
# {milk} -> support: 0.32055
# {milk, shoes} -> support: 0.01182
# {milk, tea} -> support: 0.01215
# {milk, tv} -> support: 0.01126
# {milk, yogurt} -> support: 0.01184
# {mobile} -> support: 0.09998
# {mobile, powerbank} -> support: 0.0352
# {mouse} -> support: 0.09896
# {mouse, pad} -> support: 0.04883
# {mouse, pad, usb} -> support: 0.03386
# {mouse, usb} -> support: 0.03386
# {oil} -> support: 0.05011
# {oil, rice} -> support: 0.05011
# {oil, rice, salt} -> support: 0.03508
# {oil, salt} -> support: 0.03508
# {pad} -> support: 0.04883
# {pad, usb} -> support: 0.03386
# {powerbank} -> support: 0.0352
# {rice} -> support: 0.05011
# {rice, salt} -> support: 0.03508
# {salt} -> support: 0.03508
# {shampoo} -> support: 0.05036
# {shampoo, soap} -> support: 0.05036
# {shampoo, soap, toothpaste} -> support: 0.03484
# {shampoo, toothpaste} -> support: 0.03484
# {shoes} -> support: 0.07072
# {shoes, tshirt} -> support: 0.03532
# {soap} -> support: 0.05036
# {soap, toothpaste} -> support: 0.03484
# {sofa} -> support: 0.05022
# {sofa, table} -> support: 0.05022
# {sugar} -> support: 0.04958
# {table} -> support: 0.05022
# {tea} -> support: 0.03714
# {toothpaste} -> support: 0.03484
# {tshirt} -> support: 0.04973
# {tv} -> support: 0.03623
# {usb} -> support: 0.03386
# {wipes} -> support: 0.05008
# {yogurt} -> support: 0.0371
#
# Association Rules:
# {baby_powder} => {laptop} (support: 0.03517, confidence: 1)
# {baby_powder} => {laptop, wipes} (support: 0.03517, confidence: 1)
# {baby_powder, laptop} => {wipes} (support: 0.03517, confidence: 1)
# {wipes} => {baby_powder, laptop} (support: 0.03517, confidence: 0.702276)
# {baby_powder, wipes} => {laptop} (support: 0.03517, confidence: 1)
# {laptop, wipes} => {baby_powder} (support: 0.03517, confidence: 0.702276)
# {baby_powder} => {wipes} (support: 0.03517, confidence: 1)
# {wipes} => {baby_powder} (support: 0.03517, confidence: 0.702276)
# {bananas} => {cereal} (support: 0.03452, confidence: 1)
# {cereal} => {bananas} (support: 0.03452, confidence: 0.697938)
# {bananas} => {cereal, milk} (support: 0.03452, confidence: 1)
# {cereal} => {bananas, milk} (support: 0.03452, confidence: 0.697938)
# {bananas, cereal} => {milk} (support: 0.03452, confidence: 1)
# {bananas, milk} => {cereal} (support: 0.03452, confidence: 1)
# {cereal, milk} => {bananas} (support: 0.03452, confidence: 0.697938)
# {bananas} => {milk} (support: 0.03452, confidence: 1)
# {beer} => {bread} (support: 0.03558, confidence: 0.704694)
# {beer} => {bread, laptop} (support: 0.03558, confidence: 0.704694)
# {beer, bread} => {laptop} (support: 0.03558, confidence: 1)
# {beer, laptop} => {bread} (support: 0.03558, confidence: 0.704694)
# {bread, laptop} => {beer} (support: 0.03558, confidence: 0.503752)
# {beer} => {bread, laptop, milk} (support: 0.03558, confidence: 0.704694)
# {beer, bread} => {laptop, milk} (support: 0.03558, confidence: 1)
# {beer, laptop} => {bread, milk} (support: 0.03558, confidence: 0.704694)
# {bread, laptop} => {beer, milk} (support: 0.03558, confidence: 0.503752)
# {beer, bread, laptop} => {milk} (support: 0.03558, confidence: 1)
# {beer, milk} => {bread, laptop} (support: 0.03558, confidence: 0.704694)
# {beer, bread, milk} => {laptop} (support: 0.03558, confidence: 1)
# {beer, laptop, milk} => {bread} (support: 0.03558, confidence: 0.704694)
# {bread, laptop, milk} => {beer} (support: 0.03558, confidence: 0.503752)
# {beer} => {bread, milk} (support: 0.03558, confidence: 0.704694)
# {beer, bread} => {milk} (support: 0.03558, confidence: 1)
# {beer, milk} => {bread} (support: 0.03558, confidence: 0.704694)
# {beer} => {laptop} (support: 0.05049, confidence: 1)
# {beer} => {laptop, milk} (support: 0.05049, confidence: 1)
# {beer, laptop} => {milk} (support: 0.05049, confidence: 1)
# {beer, milk} => {laptop} (support: 0.05049, confidence: 1)
# {laptop, milk} => {beer} (support: 0.05049, confidence: 0.59025)
# {beer} => {milk} (support: 0.05049, confidence: 1)
# {butter} => {bread} (support: 0.15111, confidence: 0.815224)
# {cheese} => {bread, butter} (support: 0.03549, confidence: 0.506421)
# {bread, cheese} => {butter} (support: 0.03549, confidence: 0.506421)
# {butter, cheese} => {bread} (support: 0.03549, confidence: 1)
# {jam} => {bread, butter} (support: 0.03534, confidence: 1)
# {bread, jam} => {butter} (support: 0.03534, confidence: 1)
# {butter, jam} => {bread} (support: 0.03534, confidence: 1)
# {butter, milk} => {bread} (support: 0.0355, confidence: 1)
# {cheese} => {bread} (support: 0.07008, confidence: 1)
# {cheese, eggs} => {bread} (support: 0.03459, confidence: 1)
# {cheese, eggs} => {bread, milk} (support: 0.03459, confidence: 1)
# {bread, cheese, eggs} => {milk} (support: 0.03459, confidence: 1)
# {cheese, milk} => {bread, eggs} (support: 0.03459, confidence: 1)
# {bread, cheese, milk} => {eggs} (support: 0.03459, confidence: 1)
# {cheese, eggs, milk} => {bread} (support: 0.03459, confidence: 1)
# {cheese, milk} => {bread} (support: 0.03459, confidence: 1)
# {bread, cookies} => {milk} (support: 0.01033, confidence: 0.672526)
# {cookies, milk} => {bread} (support: 0.01033, confidence: 0.798917)
# {eggs} => {bread} (support: 0.13543, confidence: 0.732014)
# {flour} => {bread, eggs} (support: 0.05045, confidence: 0.504349)
# {bread, flour} => {eggs} (support: 0.05045, confidence: 1)
# {eggs, flour} => {bread} (support: 0.05045, confidence: 0.504349)
# {bread, flour} => {eggs, milk} (support: 0.0351, confidence: 0.695738)
# {bread, eggs, flour} => {milk} (support: 0.0351, confidence: 0.695738)
# {flour, milk} => {bread, eggs} (support: 0.0351, confidence: 1)
# {bread, flour, milk} => {eggs} (support: 0.0351, confidence: 1)
# {eggs, flour, milk} => {bread} (support: 0.0351, confidence: 1)
# {eggs} => {bread, milk} (support: 0.12008, confidence: 0.649046)
# {bread, eggs} => {milk} (support: 0.12008, confidence: 0.886657)
# {eggs, milk} => {bread} (support: 0.12008, confidence: 1)
# {flour} => {bread} (support: 0.05045, confidence: 0.504349)
# {bread, flour} => {milk} (support: 0.0351, confidence: 0.695738)
# {flour, milk} => {bread} (support: 0.0351, confidence: 1)
# {jam} => {bread} (support: 0.03534, confidence: 1)
# {bread, laptop} => {milk} (support: 0.07063, confidence: 1)
# {laptop, milk} => {bread} (support: 0.07063, confidence: 0.825696)
# {bread} => {milk} (support: 0.25618, confidence: 0.661724)
# {milk} => {bread} (support: 0.25618, confidence: 0.799189)
# {cheese} => {butter} (support: 0.03549, confidence: 0.506421)
# {butter, eggs} => {flour} (support: 0.03425, confidence: 1)
# {butter, flour} => {eggs} (support: 0.03425, confidence: 1)
# {butter, eggs} => {flour, sugar} (support: 0.03425, confidence: 1)
# {butter, flour} => {eggs, sugar} (support: 0.03425, confidence: 1)
# {butter, eggs, flour} => {sugar} (support: 0.03425, confidence: 1)
# {sugar} => {butter, eggs, flour} (support: 0.03425, confidence: 0.690803)
# {butter, sugar} => {eggs, flour} (support: 0.03425, confidence: 1)
# {eggs, sugar} => {butter, flour} (support: 0.03425, confidence: 0.690803)
# {butter, eggs, sugar} => {flour} (support: 0.03425, confidence: 1)
# {flour, sugar} => {butter, eggs} (support: 0.03425, confidence: 0.690803)
# {butter, flour, sugar} => {eggs} (support: 0.03425, confidence: 1)
# {eggs, flour, sugar} => {butter} (support: 0.03425, confidence: 0.690803)
# {butter, eggs} => {sugar} (support: 0.03425, confidence: 1)
# {sugar} => {butter, eggs} (support: 0.03425, confidence: 0.690803)
# {butter, sugar} => {eggs} (support: 0.03425, confidence: 1)
# {eggs, sugar} => {butter} (support: 0.03425, confidence: 0.690803)
# {butter, flour} => {sugar} (support: 0.03425, confidence: 1)
# {sugar} => {butter, flour} (support: 0.03425, confidence: 0.690803)
# {butter, sugar} => {flour} (support: 0.03425, confidence: 1)
# {flour, sugar} => {butter} (support: 0.03425, confidence: 0.690803)
# {jam} => {butter} (support: 0.03534, confidence: 1)
# {sugar} => {butter} (support: 0.03425, confidence: 0.690803)
# {cereal} => {milk} (support: 0.04946, confidence: 1)
# {chair} => {sofa} (support: 0.03522, confidence: 1)
# {sofa} => {chair} (support: 0.03522, confidence: 0.701314)
# {chair} => {sofa, table} (support: 0.03522, confidence: 1)
# {sofa} => {chair, table} (support: 0.03522, confidence: 0.701314)
# {chair, sofa} => {table} (support: 0.03522, confidence: 1)
# {table} => {chair, sofa} (support: 0.03522, confidence: 0.701314)
# {chair, table} => {sofa} (support: 0.03522, confidence: 1)
# {sofa, table} => {chair} (support: 0.03522, confidence: 0.701314)
# {chair} => {table} (support: 0.03522, confidence: 1)
# {table} => {chair} (support: 0.03522, confidence: 0.701314)
# {charger} => {cover} (support: 0.03482, confidence: 0.701309)
# {cover} => {charger} (support: 0.03482, confidence: 1)
# {charger} => {cover, mobile} (support: 0.03482, confidence: 0.701309)
# {cover} => {charger, mobile} (support: 0.03482, confidence: 1)
# {charger, cover} => {mobile} (support: 0.03482, confidence: 1)
# {charger, mobile} => {cover} (support: 0.03482, confidence: 0.701309)
# {cover, mobile} => {charger} (support: 0.03482, confidence: 1)
# {charger} => {mobile} (support: 0.04965, confidence: 1)
# {cheese, eggs} => {milk} (support: 0.03459, confidence: 1)
# {cheese, milk} => {eggs} (support: 0.03459, confidence: 1)
# {chips} => {chocolate} (support: 0.03486, confidence: 0.704669)
# {chocolate} => {chips} (support: 0.03486, confidence: 1)
# {chips} => {chocolate, coke} (support: 0.03486, confidence: 0.704669)
# {chocolate} => {chips, coke} (support: 0.03486, confidence: 1)
# {chips, chocolate} => {coke} (support: 0.03486, confidence: 1)
# {coke} => {chips, chocolate} (support: 0.03486, confidence: 0.704669)
# {chips, coke} => {chocolate} (support: 0.03486, confidence: 0.704669)
# {chocolate, coke} => {chips} (support: 0.03486, confidence: 1)
# {chips} => {coke} (support: 0.04947, confidence: 1)
# {coke} => {chips} (support: 0.04947, confidence: 1)
# {chocolate} => {coke} (support: 0.03486, confidence: 1)
# {coke} => {chocolate} (support: 0.03486, confidence: 0.704669)
# {cover} => {mobile} (support: 0.03482, confidence: 1)
# {dal} => {oil} (support: 0.05011, confidence: 1)
# {oil} => {dal} (support: 0.05011, confidence: 1)
# {dal} => {oil, rice} (support: 0.05011, confidence: 1)
# {oil} => {dal, rice} (support: 0.05011, confidence: 1)
# {dal, oil} => {rice} (support: 0.05011, confidence: 1)
# {rice} => {dal, oil} (support: 0.05011, confidence: 1)
# {dal, rice} => {oil} (support: 0.05011, confidence: 1)
# {oil, rice} => {dal} (support: 0.05011, confidence: 1)
# {dal} => {oil, rice, salt} (support: 0.03508, confidence: 0.70006)
# {oil} => {dal, rice, salt} (support: 0.03508, confidence: 0.70006)
# {dal, oil} => {rice, salt} (support: 0.03508, confidence: 0.70006)
# {rice} => {dal, oil, salt} (support: 0.03508, confidence: 0.70006)
# {dal, rice} => {oil, salt} (support: 0.03508, confidence: 0.70006)
# {oil, rice} => {dal, salt} (support: 0.03508, confidence: 0.70006)
# {dal, oil, rice} => {salt} (support: 0.03508, confidence: 0.70006)
# {salt} => {dal, oil, rice} (support: 0.03508, confidence: 1)
# {dal, salt} => {oil, rice} (support: 0.03508, confidence: 1)
# {oil, salt} => {dal, rice} (support: 0.03508, confidence: 1)
# {dal, oil, salt} => {rice} (support: 0.03508, confidence: 1)
# {rice, salt} => {dal, oil} (support: 0.03508, confidence: 1)
# {dal, rice, salt} => {oil} (support: 0.03508, confidence: 1)
# {oil, rice, salt} => {dal} (support: 0.03508, confidence: 1)
# {dal} => {oil, salt} (support: 0.03508, confidence: 0.70006)
# {oil} => {dal, salt} (support: 0.03508, confidence: 0.70006)
# {dal, oil} => {salt} (support: 0.03508, confidence: 0.70006)
# {salt} => {dal, oil} (support: 0.03508, confidence: 1)
# {dal, salt} => {oil} (support: 0.03508, confidence: 1)
# {oil, salt} => {dal} (support: 0.03508, confidence: 1)
# {dal} => {rice} (support: 0.05011, confidence: 1)
# {rice} => {dal} (support: 0.05011, confidence: 1)
# {dal} => {rice, salt} (support: 0.03508, confidence: 0.70006)
# {rice} => {dal, salt} (support: 0.03508, confidence: 0.70006)
# {dal, rice} => {salt} (support: 0.03508, confidence: 0.70006)
# {salt} => {dal, rice} (support: 0.03508, confidence: 1)
# {dal, salt} => {rice} (support: 0.03508, confidence: 1)
# {rice, salt} => {dal} (support: 0.03508, confidence: 1)
# {dal} => {salt} (support: 0.03508, confidence: 0.70006)
# {salt} => {dal} (support: 0.03508, confidence: 1)
# {eggs} => {flour} (support: 0.10003, confidence: 0.540673)
# {flour} => {eggs} (support: 0.10003, confidence: 1)
# {flour, milk} => {eggs} (support: 0.0351, confidence: 1)
# {sugar} => {eggs, flour} (support: 0.04958, confidence: 1)
# {eggs, sugar} => {flour} (support: 0.04958, confidence: 1)
# {flour, sugar} => {eggs} (support: 0.04958, confidence: 1)
# {eggs} => {milk} (support: 0.12008, confidence: 0.649046)
# {sugar} => {eggs} (support: 0.04958, confidence: 1)
# {sugar} => {flour} (support: 0.04958, confidence: 1)
# {headphones} => {mobile} (support: 0.05033, confidence: 1)
# {mobile} => {headphones} (support: 0.05033, confidence: 0.503401)
# {headphones} => {mobile, powerbank} (support: 0.0352, confidence: 0.699384)
# {headphones, mobile} => {powerbank} (support: 0.0352, confidence: 0.699384)
# {powerbank} => {headphones, mobile} (support: 0.0352, confidence: 1)
# {headphones, powerbank} => {mobile} (support: 0.0352, confidence: 1)
# {mobile, powerbank} => {headphones} (support: 0.0352, confidence: 1)
# {headphones} => {powerbank} (support: 0.0352, confidence: 0.699384)
# {powerbank} => {headphones} (support: 0.0352, confidence: 1)
# {jeans} => {shoes} (support: 0.03532, confidence: 0.710235)
# {jeans} => {shoes, tshirt} (support: 0.03532, confidence: 0.710235)
# {jeans, shoes} => {tshirt} (support: 0.03532, confidence: 1)
# {tshirt} => {jeans, shoes} (support: 0.03532, confidence: 0.710235)
# {jeans, tshirt} => {shoes} (support: 0.03532, confidence: 0.710235)
# {shoes, tshirt} => {jeans} (support: 0.03532, confidence: 1)
# {jeans} => {tshirt} (support: 0.04973, confidence: 1)
# {tshirt} => {jeans} (support: 0.04973, confidence: 1)
# {keyboard} => {laptop} (support: 0.03502, confidence: 1)
# {keyboard} => {laptop, mouse} (support: 0.03502, confidence: 1)
# {keyboard, laptop} => {mouse} (support: 0.03502, confidence: 1)
# {keyboard, mouse} => {laptop} (support: 0.03502, confidence: 1)
# {keyboard} => {mouse} (support: 0.03502, confidence: 1)
# {mouse} => {laptop} (support: 0.09896, confidence: 1)
# {pad} => {laptop, mouse} (support: 0.04883, confidence: 1)
# {laptop, pad} => {mouse} (support: 0.04883, confidence: 1)
# {mouse, pad} => {laptop} (support: 0.04883, confidence: 1)
# {pad} => {laptop, mouse, usb} (support: 0.03386, confidence: 0.693426)
# {laptop, pad} => {mouse, usb} (support: 0.03386, confidence: 0.693426)
# {mouse, pad} => {laptop, usb} (support: 0.03386, confidence: 0.693426)
# {laptop, mouse, pad} => {usb} (support: 0.03386, confidence: 0.693426)
# {usb} => {laptop, mouse, pad} (support: 0.03386, confidence: 1)
# {laptop, usb} => {mouse, pad} (support: 0.03386, confidence: 1)
# {mouse, usb} => {laptop, pad} (support: 0.03386, confidence: 1)
# {laptop, mouse, usb} => {pad} (support: 0.03386, confidence: 1)
# {pad, usb} => {laptop, mouse} (support: 0.03386, confidence: 1)
# {laptop, pad, usb} => {mouse} (support: 0.03386, confidence: 1)
# {mouse, pad, usb} => {laptop} (support: 0.03386, confidence: 1)
# {usb} => {laptop, mouse} (support: 0.03386, confidence: 1)
# {laptop, usb} => {mouse} (support: 0.03386, confidence: 1)
# {mouse, usb} => {laptop} (support: 0.03386, confidence: 1)
# {pad} => {laptop} (support: 0.04883, confidence: 1)
# {pad} => {laptop, usb} (support: 0.03386, confidence: 0.693426)
# {laptop, pad} => {usb} (support: 0.03386, confidence: 0.693426)
# {usb} => {laptop, pad} (support: 0.03386, confidence: 1)
# {laptop, usb} => {pad} (support: 0.03386, confidence: 1)
# {pad, usb} => {laptop} (support: 0.03386, confidence: 1)
# {usb} => {laptop} (support: 0.03386, confidence: 1)
# {wipes} => {laptop} (support: 0.05008, confidence: 1)
# {powerbank} => {mobile} (support: 0.0352, confidence: 1)
# {pad} => {mouse} (support: 0.04883, confidence: 1)
# {pad} => {mouse, usb} (support: 0.03386, confidence: 0.693426)
# {mouse, pad} => {usb} (support: 0.03386, confidence: 0.693426)
# {usb} => {mouse, pad} (support: 0.03386, confidence: 1)
# {mouse, usb} => {pad} (support: 0.03386, confidence: 1)
# {pad, usb} => {mouse} (support: 0.03386, confidence: 1)
# {usb} => {mouse} (support: 0.03386, confidence: 1)
# {oil} => {rice} (support: 0.05011, confidence: 1)
# {rice} => {oil} (support: 0.05011, confidence: 1)
# {oil} => {rice, salt} (support: 0.03508, confidence: 0.70006)
# {rice} => {oil, salt} (support: 0.03508, confidence: 0.70006)
# {oil, rice} => {salt} (support: 0.03508, confidence: 0.70006)
# {salt} => {oil, rice} (support: 0.03508, confidence: 1)
# {oil, salt} => {rice} (support: 0.03508, confidence: 1)
# {rice, salt} => {oil} (support: 0.03508, confidence: 1)
# {oil} => {salt} (support: 0.03508, confidence: 0.70006)
# {salt} => {oil} (support: 0.03508, confidence: 1)
# {pad} => {usb} (support: 0.03386, confidence: 0.693426)
# {usb} => {pad} (support: 0.03386, confidence: 1)
# {rice} => {salt} (support: 0.03508, confidence: 0.70006)
# {salt} => {rice} (support: 0.03508, confidence: 1)
# {shampoo} => {soap} (support: 0.05036, confidence: 1)
# {soap} => {shampoo} (support: 0.05036, confidence: 1)
# {shampoo} => {soap, toothpaste} (support: 0.03484, confidence: 0.691819)
# {soap} => {shampoo, toothpaste} (support: 0.03484, confidence: 0.691819)
# {shampoo, soap} => {toothpaste} (support: 0.03484, confidence: 0.691819)
# {toothpaste} => {shampoo, soap} (support: 0.03484, confidence: 1)
# {shampoo, toothpaste} => {soap} (support: 0.03484, confidence: 1)
# {soap, toothpaste} => {shampoo} (support: 0.03484, confidence: 1)
# {shampoo} => {toothpaste} (support: 0.03484, confidence: 0.691819)
# {toothpaste} => {shampoo} (support: 0.03484, confidence: 1)
# {tshirt} => {shoes} (support: 0.03532, confidence: 0.710235)
# {soap} => {toothpaste} (support: 0.03484, confidence: 0.691819)
# {toothpaste} => {soap} (support: 0.03484, confidence: 1)
# {sofa} => {table} (support: 0.05022, confidence: 1)
# {table} => {sofa} (support: 0.05022, confidence: 1)

# %% [markdown]
# ##Performance Improvements Noticed
# -- Last Code Cell took 2 seconds to run and process the 1 Lakhs Record Dataset
